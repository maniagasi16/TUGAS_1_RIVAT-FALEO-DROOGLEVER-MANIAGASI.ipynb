# %%
print ("Perkenalkan Nama Saya")
# Out:
# Perkenalkan Nama Saya

# %%
Nama_depan = ' Rivat'
Nama_tengah = " Faleo Drooglever"
Nama_belakang = ' Maniagasi'
print (Nama_depan + Nama_tengah + Nama_belakang) 
NIM = input ("Dengan NIM")
jurusan = input ('Prodi')
# Out:
#  Rivat Faleo Drooglever Maniagasi
# Dengan NIM 2308541023
# Prodi Matematika

# %%
print ("Saya Akan Membuat Tugas Algoritma Tentang Operasi Bulat")
# Out:
# Saya Akan Membuat Tugas Algoritma Tentang Operasi Bulat

# %%
print ("Pemograman Operasi Bilangan Bulat")
tambah = 10 + 20 + 30 
kurang = 30 - 20 - 10
kali = 10 * 20 * 30
bagi = 30 / 20 / 10
print ("Hasil : ", tambah)
print ("Hasil : ", kurang)
print ("Hasil : ", kali)
print ("Hasil : ", bagi)
# Out:
# Pemograman Operasi Bilangan Bulat
# Hasil :  60
# Hasil :  0
# Hasil :  6000
# Hasil :  0.15
